# %%
# Importing the libraries
import numpy as np
import pandas as pd
import math

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
import pickle
import os
from datetime import datetime
import warnings

warnings.filterwarnings('ignore')

# %%
pip install numpy pandas seaborn scikit-learn statsmodels
# Out:
# Requirement already satisfied: numpy in d:\desktop\spring2\env\lib\site-packages (2.3.4)
# Requirement already satisfied: pandas in d:\desktop\spring2\env\lib\site-packages (2.3.3)
# Requirement already satisfied: seaborn in d:\desktop\spring2\env\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in d:\desktop\spring2\env\lib\site-packages (1.7.2)
# Requirement already satisfied: statsmodels in d:\desktop\spring2\env\lib\site-packages (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\desktop\spring2\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\desktop\spring2\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\desktop\spring2\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\desktop\spring2\env\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: scipy>=1.8.0 in d:\desktop\spring2\env\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\desktop\spring2\env\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\desktop\spring2\env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\desktop\spring2\env\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in d:\desktop\spring2\env\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\desktop\spring2\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\desktop\spring2\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\desktop\spring2\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\desktop\spring2\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: pillow>=8 in d:\desktop\spring2\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\desktop\spring2\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: six>=1.5 in d:\desktop\spring2\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
SPLIT_METHOD = 'time'  # 'time' or 'random'
DATA_PATH = "C:\\Users\\harip\\Desktop\\RideWise-Predicting-Bike-sharing-Demand\\Data\\EDA_WITH_VIF_DATA.csv"
OUTPUT_DIR = "."
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### LINEAR REGRESSION

# %% [markdown]
# #### 1. Importing necessary libraries

# %%
# lets import train test split for splitting the data
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import os
import joblib

# %% [markdown]
# #### 2. Splitting Train & Test dataset

# %%
# Creating a dependent variable for rented bike count
dependent_variable = 'cnt'

# %%
# Create a list of independent variables
independent_variables = list(set(df.columns.tolist()) - {dependent_variable})
independent_variables
# Out:
# ['weathersit',
#  'season_2',
#  'windspeed',
#  'temp',
#  'yr',
#  'weekday',
#  'season_3',
#  'mnth',
#  'holiday',
#  'workingday',
#  'season_4']

# %%
# Create the dependent variable data
y = np.sqrt(df['cnt'])

# Create the data of independent variables
X = df.drop('cnt',axis=1)

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train[0:10]
# Out:
#            yr  mnth  holiday  weekday  workingday  weathersit      temp  \
# 97  -1.001369     4        0        5           1           2 -0.872222
# 503  0.998633     5        0        5           1           1  0.376012
# 642  0.998633    10        0        4           1           2  0.886235
# 498  0.998633     5        0        0           0           1  0.640234
# 303 -1.001369    10        0        1           1           1 -0.849442
# 570  0.998633     7        0        2           1           1  1.396458
# 250 -1.001369     9        0        4           1           3  0.757292
# 17  -1.001369     1        0        2           1           2 -1.523666
# 595  0.998633     8        0        6           0           1  1.000123
# 240 -1.001369     8        0        1           1           1  0.772347
#
#      windspeed  season_2  season_3  season_4
# 97    0.471378      True     False     False
# 503  -0.692999      True     False     False
# 642  -0.941834     False     False      True
# 498   0.447167      True     False     False
# 303  -1.086402     False     False      True
# 570   0.270745     False      True     False
# 250   0.029205     False      True     False
# 17   -0.564417     False     False     False
# 595  -0.162945     False      True     False
# 240  -0.395910     False      True     False

# %%
# Transforming data 
scaler = MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
# Your specific directory
save_dir = r"C:\Users\harip\Desktop\RideWise-Predicting-Bike-sharing-Demand\Modeling\saved_models"

# Create folder if missing
os.makedirs(save_dir, exist_ok=True)

# Final file path
save_path = os.path.join(save_dir, "lr_scaler.pkl")

# Save scaler
with open(save_path, 'wb') as f:
    joblib.dump(scaler, f)

print(f"Scaler saved successfully at: {save_path}")
# Out:
# Scaler saved successfully at: C:\Users\harip\Desktop\RideWise-Predicting-Bike-sharing-Demand\Modeling\saved_models\lr_scaler.pkl

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Checking shape
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (584, 11)
# (584,)
# (147, 11)
# (147,)

# %%
X_train[0:10]
# Out:
# array([[0.        , 0.27272727, 0.        , 0.83333333, 1.        ,
#         0.5       , 0.35024023, 0.48605788, 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.36363636, 0.        , 0.83333333, 1.        ,
#         0.        , 0.63925722, 0.24873701, 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.81818182, 0.        , 0.66666667, 1.        ,
#         0.5       , 0.75739478, 0.19801995, 0.        , 0.        ,
#         1.        ],
#        [1.        , 0.36363636, 0.        , 0.        , 0.        ,
#         0.        , 0.7004354 , 0.48112329, 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.81818182, 0.        , 0.16666667, 1.        ,
#         0.        , 0.35551467, 0.16855453, 0.        , 0.        ,
#         1.        ],
#        [1.        , 0.54545455, 0.        , 0.33333333, 1.        ,
#         0.        , 0.87553235, 0.44516526, 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.72727273, 0.        , 0.66666667, 1.        ,
#         1.        , 0.72753921, 0.39593516, 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.33333333, 1.        ,
#         0.5       , 0.19940418, 0.27494429, 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.63636364, 0.        , 1.        , 0.        ,
#         0.        , 0.78376445, 0.35677163, 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.63636364, 0.        , 0.16666667, 1.        ,
#         0.        , 0.73102512, 0.30928903, 0.        , 1.        ,
#         0.        ]])

# %% [markdown]
# #### 3. Model building with training & testing

# %%
# Fitting Multiple Linear Regression to the Training set
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import joblib
joblib.dump(regressor, r"C:\Users\harip\Desktop\RideWise-Predicting-Bike-sharing-Demand\Modeling\saved_models\linear_regression.pkl")
# Out:
# ['C:\\Users\\harip\\Desktop\\RideWise-Predicting-Bike-sharing-Demand\\Modeling\\saved_models\\linear_regression.pkl']

# %%
# Cheeck coefficents
regressor.coef_
# Out:
# array([ 15.29868871,  -1.23866693,  -3.87010658,   3.01756277,
#          0.95189132, -13.46518336,  32.70987169,  -8.56731923,
#          9.1108743 ,   6.86903426,  12.76714928])

# %%
pd.DataFrame(regressor.coef_,X.columns, columns=['Coefficient'])
# Out:
#             Coefficient
# yr            15.298689
# mnth          -1.238667
# holiday       -3.870107
# weekday        3.017563
# workingday     0.951891
# weathersit   -13.465183
# temp          32.709872
# windspeed     -8.567319
# season_2       9.110874
# season_3       6.869034
# season_4      12.767149

# %%
# Check intercept
regressor.intercept_
# Out:
# np.float64(36.950710749664594)

# %%
# Checking score
regressor.score(X_train,y_train)
# Out:
# 0.7972370239148932

# %%
# Y peredictions on train data
y_pred_train = regressor.predict(X_train)

# y predictions on test data
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Calculated values insights
#
# Growth over time (yr ↑)
#
# Warm weather boosts demand (temp ↑)
#
# Wind & bad weather kill demand (weathersit, windspeed ↓)
#
# Holidays slightly drop rentals
#
# Working days bring consistent traffic

# %% [markdown]
# | **Term**     | **Represents**   | **Model Insight**                           |
# | ------------ | ---------------- | ------------------------------------------- |
# | `coef_`      | Feature weights  | Shows feature importance and direction.     |
# | `intercept_` | Base value       | Predicted value when all features = 0.      |
# | `score()`    | R²               | Fit quality (closer to 1 → better).         |
# | `predict()`  | Model inference  | Produces predictions using learned weights. |
# | `fit()`      | Training process | Finds optimal coefficients.                 |

# %% [markdown]
# #### 4. Model evaluation

# %%
import numpy as np
import pickle
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score



# ---------------------------------------------------
# 1) Calculate metrics + Print + Auto-store + Auto-save
# ---------------------------------------------------
def evaluate_and_store(model_name, y_true, y_pred, X_test, results_df, save_path="test_result.pkl"):
    # ---- Calculate Metrics ----
    MAE  = mean_absolute_error(y_true, y_pred)
    MSE  = mean_squared_error(y_true, y_pred)
    RMSE = np.sqrt(MSE)
    R2   = r2_score(y_true, y_pred)
    adj_r2 = 1 - (1 - R2) * ((X_test.shape[0] - 1) / (X_test.shape[0] - X_test.shape[1] - 1))

    # ---- Print like you wanted ----
    print(f"{model_name}: ['MAE': {round(MAE,3)}, 'MSE': {round(MSE,3)}, "
          f"'R2': {round(R2,3)}, 'RMSE': {round(RMSE,3)}, 'adj_r2': {round(adj_r2,3)}]")

    # ---- Prepare dictionary for storage ----
    metrics_dict = {
        "Model": model_name,
        "MAE": round(MAE, 4),
        "MSE": round(MSE, 4),
        "RMSE": round(RMSE, 4),
        "R2_score": round(R2, 4),
        "Adjusted_R2": round(adj_r2, 4)
    }

    # ---- Append only if model doesn't exist ----
    if model_name not in results_df["Model"].values:
        results_df = pd.concat([results_df, pd.DataFrame([metrics_dict])], ignore_index=True)
    else:
        print(f" Model '{model_name}' already exists. Skipping append.")

    # ---- Save updated dataframe ----
    with open(save_path, 'wb') as f:
        pickle.dump(results_df, f)

    print(f"✔ Results saved to {save_path}")

    return results_df

# %%
test_result_df = pd.DataFrame()

# %%
test_result_df = evaluate_and_store(
    model_name="Linear Regression",
    y_true=y_test,
    y_pred=y_pred,
    X_test=X_test,
    results_df=test_result_df,
    save_path="test_result.pkl"
)
# Out:
# Linear Regression: ['MAE': 4.837, 'MSE': 40.489, 'R2': 0.857, 'RMSE': 6.363, 'adj_r2': 0.846]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 test_result_df = evaluate_and_store(
#       2     model_name="Linear Regression",
#       3     y_true=y_test,
#       4     y_pred=y_pred,
#       5     X_test=X_test,
#       6     results_df=test_results_df,
#       7     save_path="test_result.pkl"
#       8 )
#
# Cell In[46], line 34, in evaluate_and_store(model_name, y_true, y_pred, X_test, results_df, save_path)
#      24 metrics_dict = {
#      25     "Model": model_name,
#      26     "MAE": round(MAE, 4),
#    (...)     30     "Adjusted_R2": round(adj_r2, 4)
#      31 }
#      33 # ---- Append only if model doesn't exist ----
# ---> 34 if model_name not in results_df["Model"].values:
#      35     results_df = pd.concat([results_df, pd.DataFrame([metrics_dict])], ignore_index=True)
#      36 else:
#
# File d:\Desktop\spring2\env\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File d:\Desktop\spring2\env\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Model'

# %% [markdown]
# With an R² of 0.8575 and balanced train–test performance, the model shows strong predictive ability and minimal overfitting. Slight prediction errors indicate scope for further improvement through non-linear modeling.

# %% [markdown]
# ### GENERAL INSIGHTS - model evaluation
#
# | Metric                        | What it Says About Model            | What High/Low Means             |
# | ----------------------------- | ----------------------------------- | ------------------------------- |
# | **R²**                        | How much variance is explained      | High → good fit                 |
# | **Adjusted R²**               | Fit adjusted for number of features | Close to R² → no junk features  |
# | **MAE**                       | Average absolute prediction error   | Low → consistent accuracy       |
# | **MSE / RMSE**                | Penalizes large prediction errors   | Low → stable + robust model     |
# | **Gap between train/test R²** | Checks overfitting                  | Small gap → good generalization |

# %%
# define a fucntion to plot predicted y values and actual y values
def plot_Pred_vs_actual(y_pred_test,y_test):
  ''' 
  Visualize predicted values with actual values.
  '''
  plt.figure(figsize=(20,8))
  plt.plot(y_pred_test)
  plt.plot(np.array(y_test))
  plt.legend(["Predicted","Actual"],)
  plt.title("Predicted V/S Actual")
  plt.show()

# %%
# define a function to plot scatter plot for y_test and y_actual.
def plot_scatter(y_pred_test,y_test):
  '''
  Plot scatter plot for y_test values and y_test values. To check how close we are to regresson line
  '''
  plt.figure(figsize=(16,5))
  sns.regplot(x = y_test,y = y_pred_test, line_kws={'color':'red'})
  plt.xlabel('Actual')
  plt.ylabel("Predicted")
  plt.title("Actual v/s Predicted")

# %%
# Residuals of the regression are normally distributed.(Homoscedasticity refers to whether these residuals are equally distributed).
def Residual_distPlot(y_pred_test,y_test):  
  '''
  Checks the distribution of residals
  '''        
                                                    
  plt.figure(figsize=(10,5))
  sns.distplot(x = y_test-y_pred_test)
  plt.title("Residual Distribution")

# %%
plot_Pred_vs_actual(y_pred,y_test)

# %%
# Check Homoscedasticity by plotting y_predicted values and the residuals
plt.figure(figsize=(16,5))
sns.regplot(x = y_pred, y = y_test-y_pred,line_kws={'color':'red'})
plt.ylabel('Residuals')
plt.xlabel('y_predicted')
# Out:
# Text(0.5, 0, 'y_predicted')

# %%
# Checking how predicted values and actual values are close  to the regression line
plot_scatter(y_pred,y_test)

# %%
Residual_distPlot(y_pred,y_test)

# %% [markdown]
# The residuals form a near-normal distribution centered around zero, which indicates that the Linear Regression model is performing well — the errors are random, balanced, and not biased in any particular direction.

# %% [markdown]
# #### GENERAL INSIGHTS - plots after model evaluation
#
# What are residuals?
#
# Residuals = (Actual value − Predicted value)
#
# They represent how far off your model’s predictions are for each data point.
#
# If residual = 0 → perfect prediction
#
# Negative residual → model overpredicted
#
# Positive residual → model underpredicted
