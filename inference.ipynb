# %%
import joblib
import os

# %%
model_path = r"/Users/harshita/vs_code/Infosys_springboard/RideWise-Predicting-Bike-sharing-Demand/Saved_model_files/gradient_boost.pkl"
model = joblib.load(open(model_path, "rb"))

# %%
model.predict([[197, 0, 0, 0, 1.0213620694601442, -0.2761785809125537,
       0.24669145169028492, 16, False, True, False, False, False, False,
       False, False, True, False, False, False, False, False, False,
       False, False, False, False, True, False, False]])
# Out:
# /Users/harshita/vs_code/Infosys_springboard/RideWise-Predicting-Bike-sharing-Demand/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([4989.13591638])
